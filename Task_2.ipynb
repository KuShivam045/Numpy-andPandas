# %%
import pandas as pd
import csvkit as cs
import mysql.connector as conn
import numpy as np
import json
import pymongo

# %%
Orders = pd.read_excel("Superstore_USA.xlsx", sheet_name= "Orders")
Orders.to_csv("Orders.csv")

# %%
returns = pd.read_excel("Superstore_USA.xlsx", sheet_name= "Returns")
returns.to_csv("Returns")

# %%
Users = pd.read_excel("Superstore_USA.xlsx", sheet_name= "Users")
Users.to_csv("Users.csv")

# %%
# !csvsql --db mysql://root:KuShi025@127.0.0.1:3306/task --insert Orders.csv
# Out:
# C:\Users\Shivaay\anaconda3\lib\site-packages\agate\table\from_csv.py:74: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# C:\Users\Shivaay\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'orders' already exists")
# [SQL:
# CREATE TABLE `Orders` (
# 	a DECIMAL(38, 0) NOT NULL,
# 	`Row ID` DECIMAL(38, 0) NOT NULL,
# 	`Order Priority` VARCHAR(13) NOT NULL,
# 	`Discount` DECIMAL(38, 2) NOT NULL,
# 	`Unit Price` DECIMAL(38, 2) NOT NULL,
# 	`Shipping Cost` DECIMAL(38, 2) NOT NULL,
# 	`Customer ID` DECIMAL(38, 0) NOT NULL,
# 	`Customer Name` VARCHAR(28) NOT NULL,
# 	`Ship Mode` VARCHAR(14) NOT NULL,
# 	`Customer Segment` VARCHAR(14) NOT NULL,
# 	`Product Category` VARCHAR(15) NOT NULL,
# 	`Product Sub-Category` VARCHAR(30) NOT NULL,
# 	`Product Container` VARCHAR(10) NOT NULL,
# 	`Product Name` VARCHAR(98) NOT NULL,
# ...

# %%
# !csvsql --db mysql://root:KuShi025@127.0.0.1:3306/task --insert Returns
# Out:
# C:\Users\Shivaay\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'returns' already exists")
# [SQL:
# CREATE TABLE `Returns` (
# 	a DECIMAL(38, 0) NOT NULL,
# 	`Order ID` DECIMAL(38, 0) NOT NULL,
# 	`Status` VARCHAR(8) NOT NULL
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1be52b29520>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
# !csvsql --db mysql://root:KuShi025@127.0.0.1:3306/task --insert Users.csv
# Out:
# C:\Users\Shivaay\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'users' already exists")
# [SQL:
# CREATE TABLE `Users` (
# 	a DECIMAL(38, 0) NOT NULL,
# 	`Region` VARCHAR(7) NOT NULL,
# 	`Manager` VARCHAR(7) NOT NULL
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1be52b29880>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\Shivaay\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
Orders.to_json('Order1.json')
returns.to_json("Return1.json")
Users.to_json("Users1.json")

# %%
client = pymongo.MongoClient("mongodb+srv://KUSHI045:KuShi025@shivam.ueoblcw.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db


Lst=["Order1.json","Users1.json","Return1.json"]

# %%
for i in range(3):  
    with open (r"C:\Users\Shivaay\\" + Lst[i]) as file:
# st is a variable that holds the file address and .strip("‪u202a") is used to avoid the error
        data = [(json.load(file))]

    db1 = client["My_info"] # ["My_info"] is the cluster/ database name
    coll = db1[Lst[i]]#["Lst[1]"] is the table name
    coll.insert_many(data)

# %% [markdown]
# # 3 . Find out how return that we ahve recived and with a product id

# %%
returns.dtypes
# Out:
# Order ID     int64
# Status      object
# dtype: object

# %%
len(returns['Order ID'].unique())
# Out:
# 1634

# %%
returns['Order ID'].count()
# Out:
# 1634

# %%
return_df = returns
order_df1 = Orders 
order_df = Orders
order_df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
order_df1 = order_df[['Row ID','Order ID','Product Sub-Category']]

# %%
return_df.merge(order_df1, on= 'Order ID')
# Out:
#     Order ID    Status  Row ID           Product Sub-Category
# 0        612  Returned      95                          Paper
# 1        612  Returned      96   Telephones and Communication
# 2       4610  Returned     653           Computer Peripherals
# 3       4610  Returned     654                      Envelopes
# 4       7079  Returned     979             Chairs & Chairmats
# ..       ...       ...     ...                            ...
# 93     57638  Returned    8079                         Tables
# 94     57638  Returned    8080                          Paper
# 95     57638  Returned    8081  Scissors, Rulers and Trimmers
# 96     59009  Returned    8251                          Paper
# 97     59937  Returned    8389                          Paper
#
# [98 rows x 4 columns]

# %% [markdown]
# # 4 . try  to join order and return data both in sql and pandas

# %%
order_df.merge(return_df,how = 'left', on = "Order ID")
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
mydb = conn.connect(host = "localhost", user = "root", passwd = "KuShi025")
print(mydb)
cursor = mydb.cursor()

# %%
# a = "create table Practice.learn(Serial_no int(5) ,Sub_1_name varchar(20), Sub_2_name varchar(20),Sub_3_name varchar(20), Sub_4_name varchar(20))"
s = cursor.execute("insert into Practice.learn values(10000, 'AI', 'Data Science','Neural Network','Cloud Computing')")
cursor.execute(s)
mydb.commit()
q2 = cursor.execute("select * from practice.learn")

for i in cursor.fetchall():

    print(i)
# Out:
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# (10000, 'AI', 'Data Science', 'Neural Network', 'Cloud Computing')
# ...

# %%
q3 = cursor.execute("select * from task.Orders")

for i in cursor.fetchall():

    print(i)
# Out:
# (Decimal('0'), Decimal('18606'), 'Not Specified', Decimal('0.01'), Decimal('2.88'), Decimal('0.50'), Decimal('2'), 'Janice Fletcher', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 49', Decimal('0.36'), 'Central', 'Illinois', 'Addison', Decimal('60101'), datetime.date(2012, 5, 28), datetime.date(2012, 5, 30), Decimal('1.320000000000000000'), Decimal('2'), Decimal('5.90'), Decimal('88525'))
# (Decimal('1'), Decimal('20847'), 'High', Decimal('0.01'), Decimal('2.84'), Decimal('0.93'), Decimal('3'), 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'SANFORD Liquid Accent™ Tank-Style Highlighters', Decimal('0.54'), 'West', 'Washington', 'Anacortes', Decimal('98221'), datetime.date(2010, 7, 7), datetime.date(2010, 7, 8), Decimal('4.560000000000000000'), Decimal('4'), Decimal('13.01'), Decimal('88522'))
# ...

# %%
q4 = cursor.execute("select * from task.Returns")

for i in cursor.fetchall():

    print(i)
# Out:
# (Decimal('0'), Decimal('65'), 'Returned')
# (Decimal('1'), Decimal('612'), 'Returned')
# (Decimal('2'), Decimal('614'), 'Returned')
# (Decimal('3'), Decimal('678'), 'Returned')
# (Decimal('4'), Decimal('710'), 'Returned')
# (Decimal('5'), Decimal('740'), 'Returned')
# (Decimal('6'), Decimal('775'), 'Returned')
# (Decimal('7'), Decimal('833'), 'Returned')
# (Decimal('8'), Decimal('902'), 'Returned')
# (Decimal('9'), Decimal('3300'), 'Returned')
# (Decimal('10'), Decimal('3456'), 'Returned')
# (Decimal('11'), Decimal('3525'), 'Returned')
# (Decimal('12'), Decimal('3589'), 'Returned')
# (Decimal('13'), Decimal('3687'), 'Returned')
# (Decimal('14'), Decimal('3777'), 'Returned')
# (Decimal('15'), Decimal('3783'), 'Returned')
# (Decimal('16'), Decimal('4006'), 'Returned')
# (Decimal('17'), Decimal('4037'), 'Returned')
# (Decimal('18'), Decimal('4230'), 'Returned')
# (Decimal('19'), Decimal('4261'), 'Returned')
# (Decimal('20'), Decimal('4391'), 'Returned')
# ...

# %% [markdown]
# # 5 . Try to find out how many unique customer that we have

# %%
order_df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
len(order_df['Customer ID'].unique())
# Out:
# 2703

# %% [markdown]
# # 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
order_df['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
order_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# df2 = order_df['Ship Date']
Reg_Air = (len(order_df[order_df['Ship Mode'] == 'Regular Air'])/len(order_df))*100
Exp_Air = (len(order_df[order_df['Ship Mode'] == 'Express Air'])/len(order_df))*100
Del_Truck = (len(order_df[order_df['Ship Mode'] == 'Delivery Truck'])/len(order_df))*100

# %%
percent = [Exp_Air,Reg_Air,Del_Truck]
for i in percent:
    print(i)
# Out:
# 11.744112030553786
# 74.64460004243581
# 13.611287927010396

# %% [markdown]
# # 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
prod = pd.DataFrame(order_df["Product Name"].unique())
k = (order_df[["Region","Product Name"]])
l = (Users[["Region","Manager"]])
managers = pd.merge(k,l,on = "Region")
managers
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %%
order_df["Delivery_Time(Days)"] = order_df["Ship Date"] - order_df["Order Date"]

# %%
order_shipdf = order_df[['Order ID','Order Date', 'Ship Date','Ship Mode','Delivery_Time(Days)']].reset_index(drop = 'index')
order_shipdf
# Out:
#       Order ID Order Date  Ship Date       Ship Mode Delivery_Time(Days)
# 0        88525 2012-05-28 2012-05-30     Regular Air              2 days
# 1        88522 2010-07-07 2010-07-08     Express Air              1 days
# 2        88523 2011-07-27 2011-07-28     Express Air              1 days
# 3        88523 2011-07-27 2011-07-28     Regular Air              1 days
# 4        88523 2011-07-27 2011-07-27     Express Air              0 days
# ...        ...        ...        ...             ...                 ...
# 9421     87532 2013-05-14 2013-05-15     Regular Air              1 days
# 9422     87532 2013-05-14 2013-05-14     Regular Air              0 days
# 9423     87533 2013-09-12 2013-09-14  Delivery Truck              2 days
# 9424     87530 2010-02-08 2010-02-11     Express Air              3 days
# 9425     87533 2013-09-12 2013-09-14     Express Air              2 days
#
# [9426 rows x 5 columns]

# %%
order_shipdf[order_shipdf['Delivery_Time(Days)'] >= '10 days'][['Order ID','Delivery_Time(Days)']].sort_values(by = 'Delivery_Time(Days)', ascending = False)
# Out:
#       Order ID Delivery_Time(Days)
# 2515     86177             92 days
# 643      87215             84 days
# 8983     19841             31 days
# 8997     87300             31 days
# 1699     19556             28 days
# 1680     87957             28 days
# 8996     87300             27 days
# 8982     19841             27 days
# 5881     91294             24 days
# 5859     87572             22 days
# 8993     19841             19 days
# 8973     87300             19 days
# 8610     86436             19 days
# 8607     86434             18 days
# 8609     86436             17 days
# 5673     88352             17 days
# 1678     87957             17 days
# 1697     19556             17 days
# 1549     86318             15 days
# 5548     88223             14 days
# 1548     86318             11 days
# 1698     19556             11 days
# 1679     87957             11 days

# %% [markdown]
# # 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
# retun = pd.DataFrame(order_shipdf["Product Name"].unique())
k = (order_df[["Order ID",'Delivery_Time(Days)','Ship Date',"Region"]])
l = (return_df[["Order ID","Status"]])
wapas = pd.merge(k,l,on = "Order ID")
pd.DataFrame(wapas)
# Out:
#     Order ID Delivery_Time(Days)  Ship Date Region    Status
# 0       9895              4 days 2011-04-24   East  Returned
# 1      13959              2 days 2010-04-06   West  Returned
# 2      13959              2 days 2010-04-06   West  Returned
# 3      36038              2 days 2013-08-18   West  Returned
# 4      39490              0 days 2013-08-12  South  Returned
# ..       ...                 ...        ...    ...       ...
# 93      7107              2 days 2013-01-06   West  Returned
# 94      7107              1 days 2013-01-05   West  Returned
# 95     42823              2 days 2013-06-27   West  Returned
# 96     13638              2 days 2012-10-02   East  Returned
# 97     47109              2 days 2012-09-13   East  Returned
#
# [98 rows x 5 columns]

# %%
wapas[wapas['Delivery_Time(Days)'] > '3 days'][['Order ID','Delivery_Time(Days)', 'Ship Date']].sort_values(by = 'Delivery_Time(Days)', ascending = True)
# Out:
#     Order ID Delivery_Time(Days)  Ship Date
# 0       9895              4 days 2011-04-24
# 5      39490              4 days 2013-08-16
# 75      4610              4 days 2011-06-21
# 21     57638              5 days 2013-04-27
# 42     41760              5 days 2013-02-01
# 44     41760              5 days 2013-02-01
# 45     41760              5 days 2013-02-01
# 89     32931              5 days 2011-02-20
# 43     41760              7 days 2013-02-03
# 88     32931              7 days 2011-02-22
# 25     51559              9 days 2013-03-13

# %%
k = (wapas[["Order ID",'Delivery_Time(Days)','Ship Date',"Region"]])
l = (Users[["Region","Manager"]])
mN = pd.merge(k,l,on = "Region")
pd.DataFrame(mN)
# Out:
#     Order ID Delivery_Time(Days)  Ship Date   Region Manager
# 0       9895              4 days 2011-04-24     East    Erin
# 1       7079              1 days 2011-02-09     East    Erin
# 2       7079              2 days 2011-02-10     East    Erin
# 3       8353              2 days 2010-05-17     East    Erin
# 4       8353              2 days 2013-05-17     East    Erin
# ..       ...                 ...        ...      ...     ...
# 93     41059              2 days 2011-09-16  Central   Chris
# 94     41059              1 days 2011-09-15  Central   Chris
# 95     13284              1 days 2013-08-13  Central   Chris
# 96     13284              1 days 2013-08-13  Central   Chris
# 97     45794              2 days 2012-09-26  Central   Chris
#
# [98 rows x 5 columns]

# %%
mN[mN['Delivery_Time(Days)'] > '5 days'][['Order ID','Delivery_Time(Days)', 'Ship Date', "Region","Manager"]].sort_values(by = 'Delivery_Time(Days)', ascending = True)
# Out:
#     Order ID Delivery_Time(Days)  Ship Date Region  Manager
# 16     41760              7 days 2013-02-03   East     Erin
# 70     32931              7 days 2011-02-22   West  William
# 48     51559              9 days 2013-03-13   West  William

# %% [markdown]
# # 11 . Group by region and find out which region is more profitable

# %%
order_df.groupby("Region")[["Profit"]].sum().sort_values(by = "Profit",ascending = False)
# Out:
#                 Profit
# Region
# Central  519825.567067
# East     377566.186045
# West     310849.453897
# South    104201.192420

# %% [markdown]
# # 12 . Try to find out overalll in which country we are giving more discount

# %%
order_df.groupby("State or Province")[["Discount"]].sum().sort_values(by = "Discount",ascending = False)
# Out:
#                       Discount
# State or Province
# California               52.28
# Texas                    31.36
# Illinois                 29.71
# New York                 28.86
# Florida                  26.38
# Ohio                     19.71
# Washington               15.48
# Michigan                 15.29
# Pennsylvania             13.32
# Minnesota                12.52
# Indiana                  12.22
# North Carolina           12.02
# Massachusetts            11.22
# Virginia                  9.80
# Georgia                   9.79
# Maryland                  8.85
# New Jersey                8.73
# Tennessee                 8.55
# Oregon                    8.42
# Missouri                  8.09
# Wisconsin                 8.06
# Colorado                  8.05
# Utah                      7.67
# Iowa                      7.15
# Kansas                    6.89
# Arizona                   6.86
# Maine                     6.66
# Alabama                   5.87
# ...

# %% [markdown]
# # 13 . Give me a list of unique postal code

# %%
order_df["Postal Code"].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# # 14 . which customer segement is more profitalble find it out .

# %%
order_df.groupby("Customer Segment")[["Profit"]].sum().reset_index()
# Out:
#   Customer Segment         Profit
# 0         Consumer  206559.625348
# 1        Corporate  505538.627783
# 2      Home Office  283869.553814
# 3   Small Business  316474.592482

# %% [markdown]
# # 15 . try to find out the 10th most loss making product catagory.

# %%
order_df.groupby("Product Sub-Category")[["Profit"]].sum().sort_values(by = "Profit", ascending = True)
# Out:
#                                        Profit
# Product Sub-Category
# Tables                          -72495.061875
# Bookcases                        -7708.748564
# Rubber Bands                     -2841.722459
# Scissors, Rulers and Trimmers    -1936.849120
# Pens & Art Supplies               1195.902840
# Storage & Organization            8078.804727
# Labels                           17775.320505
# Paper                            35361.621738
# Envelopes                        46133.223840
# Computer Peripherals             87917.842513
# Office Furnishings               92209.225867
# Appliances                      121651.391380
# Copiers and Fax                 129156.684030
# Chairs & Chairmats              165348.882760
# Office Machines                 168072.833340
# Binders and Binder Accessories  226572.523042
# Telephones and Communication    297950.524866

# %% [markdown]
# # 16 . Try to find out 10 top  product with highest margins

# %%
v = order_df.groupby('Product Sub-Category')[['Product Base Margin']].sum().sort_values(by = 'Product Base Margin', ascending = False).reset_index()

# %%
v.loc[1:10]
# Out:
#               Product Sub-Category  Product Base Margin
# 1                            Paper               517.09
# 2             Computer Peripherals               500.91
# 3               Office Furnishings               463.23
# 4           Storage & Organization               390.26
# 5   Binders and Binder Accessories               384.57
# 6              Pens & Art Supplies               384.57
# 7                       Appliances               273.00
# 8                           Tables               271.19
# 9               Chairs & Chairmats               260.59
# 10                 Office Machines               167.64
