# %%
import pandas as pd

df = pd.read_csv('AgentPerformance.csv')
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback
# 0                    0:04:20            4.11               9
# 1                    0:28:25            3.14               7
# 2                    0:11:36            4.55              11
# 3                    0:15:46            4.71               7
# 4                    0:16:33            3.67               6
# ...                      ...             ...             ...
# 2155                 0:00:00            0.00               0
# 2156                 0:00:00            0.00               0
# 2157                 0:00:00            0.00               0
# 2158                 0:00:00            0.00               0
# 2159                 0:00:00            0.00               0
#
# [2160 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %%
date = pd.to_datetime(df['Date'])
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_date'] = date
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback converted_date
# 0                 0:04:20            4.11               9     2022-07-30
# 1                 0:28:25            3.14               7     2022-07-30
# 2                 0:11:36            4.55              11     2022-07-30
# 3                 0:15:46            4.71               7     2022-07-30
# 4                 0:16:33            3.67               6     2022-07-30

# %%
df['year'] = df['converted_date'].dt.year
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback converted_date  year
# 0                 0:04:20            4.11               9     2022-07-30  2022
# 1                 0:28:25            3.14               7     2022-07-30  2022
# 2                 0:11:36            4.55              11     2022-07-30  2022
# 3                 0:15:46            4.71               7     2022-07-30  2022
# 4                 0:16:33            3.67               6     2022-07-30  2022

# %%
df['week'] = df['converted_date'].dt.week
df
# Out:
# C:\Users\Shivaay\AppData\Local\Temp\ipykernel_7968\16947380.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['converted_date'].dt.week
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                    0:04:20            4.11               9     2022-07-30
# 1                    0:28:25            3.14               7     2022-07-30
# 2                    0:11:36            4.55              11     2022-07-30
# 3                    0:15:46            4.71               7     2022-07-30
# 4                    0:16:33            3.67               6     2022-07-30
# ...                      ...             ...             ...            ...
# 2155                 0:00:00            0.00               0     2022-07-01
# 2156                 0:00:00            0.00               0     2022-07-01
# 2157                 0:00:00            0.00               0     2022-07-01
# 2158                 0:00:00            0.00               0     2022-07-01
# 2159                 0:00:00            0.00               0     2022-07-01
#
#       year  week
# 0     2022    30
# 1     2022    30
# 2     2022    30
# 3     2022    30
# 4     2022    30
# ...    ...   ...
# 2155  2022    26
# 2156  2022    26
# 2157  2022    26
# 2158  2022    26
# 2159  2022    26
#
# [2160 rows x 11 columns]

# %%
df['month'] = df['converted_date'].dt.month
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                    0:04:20            4.11               9     2022-07-30
# 1                    0:28:25            3.14               7     2022-07-30
# 2                    0:11:36            4.55              11     2022-07-30
# 3                    0:15:46            4.71               7     2022-07-30
# 4                    0:16:33            3.67               6     2022-07-30
# ...                      ...             ...             ...            ...
# 2155                 0:00:00            0.00               0     2022-07-01
# 2156                 0:00:00            0.00               0     2022-07-01
# 2157                 0:00:00            0.00               0     2022-07-01
# 2158                 0:00:00            0.00               0     2022-07-01
# 2159                 0:00:00            0.00               0     2022-07-01
#
#       year  week  month
# 0     2022    30      7
# 1     2022    30      7
# 2     2022    30      7
# 3     2022    30      7
# 4     2022    30      7
# ...    ...   ...    ...
# 2155  2022    26      7
# 2156  2022    26      7
# 2157  2022    26      7
# 2158  2022    26      7
# 2159  2022    26      7
#
# [2160 rows x 12 columns]

# %%
# df['days'] = df['converted_date'].dt.day

df. rename(columns = {'days':'working_days'}, inplace = True)

# %% [markdown]
# # Answer number 2
# 3. Total query that you hvae taken

# %%
for  i in df['working_days']:
    
    df['working_days'].mask(df['working_days'] == i,"present", inplace=True)

# %%
df.head(240)
# Out:
#      SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0        1  7/30/2022        Prerna Singh           11               0:00:38
# 1        2  7/30/2022       Nandani Gupta           11               0:01:15
# 2        3  7/30/2022          Ameya Jain           14               0:00:30
# 3        4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4        5  7/30/2022              Swati            14               0:01:11
# ..     ...        ...                 ...          ...                   ...
# 235    236  7/27/2022              Wasim            25               0:01:05
# 236    237  7/27/2022   Sowmiya Sivakumar           19               0:00:44
# 237    238  7/27/2022     Hrisikesh Neogi           20               0:01:25
# 238    239  7/27/2022  Harikrishnan Shaji           17               0:00:35
# 239    240  7/27/2022        Manjunatha A           18               0:01:04
#
#     Average Resolution Time  Average Rating  Total Feedback converted_date  \
# 0                   0:04:20            4.11               9     2022-07-30
# 1                   0:28:25            3.14               7     2022-07-30
# 2                   0:11:36            4.55              11     2022-07-30
# 3                   0:15:46            4.71               7     2022-07-30
# 4                   0:16:33            3.67               6     2022-07-30
# ..                      ...             ...             ...            ...
# 235                 0:27:15            4.53              17     2022-07-27
# 236                 0:07:54            4.29              14     2022-07-27
# 237                 0:21:08            4.40              15     2022-07-27
# 238                 0:10:25            4.50              12     2022-07-27
# 239                 0:24:54            4.54              13     2022-07-27
#
#      year  week  month  rating working_days
# 0    2022    30      7     NaN      present
# 1    2022    30      7     NaN      present
# 2    2022    30      7     NaN      present
# 3    2022    30      7     NaN      present
# 4    2022    30      7     NaN      present
# ..    ...   ...    ...     ...          ...
# 235  2022    30      7     NaN      present
# 236  2022    30      7     NaN      present
# 237  2022    30      7     NaN      present
# 238  2022    30      7     NaN      present
# 239  2022    30      7     NaN      present
#
# [240 rows x 14 columns]

# %%
df.groupby('Agent Name')['days'].value_counts()
# Out:
# Agent Name     days
# Abhishek       present    30
# Aditya         present    30
# Aditya Shinde  present    30
# Aditya_iot     present    30
# Amersh         present    30
#                           ..
# Uday Mishra    present    30
# Vasanth P      present    30
# Vivek          present    30
# Wasim          present    30
# Zeeshan        present    30
# Name: days, Length: 70, dtype: int64

# %%
df[df.groupby(a)['week'].mean()].index
# Out:
# RangeIndex(start=0, stop=2160, step=1)

# %% [markdown]
# # Answer Number 3
# 3. Total query that you hvae taken

# %%
df.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# # Answer Numner 4
# 4. total Feedback that you have received

# %%
df.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %% [markdown]
# # Answer Number 5
# 5. a agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating'] >=3.5) & (df['Average Rating'] <= 4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 114, dtype: object

# %% [markdown]
# # Answer Number 6
# 6 . Agent name who have rating lesss then 3.5

# %%
df[df['Average Rating'] < 3.5]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %% [markdown]
# # Answer Number 7
# 7 . agent name who have rating more then 4.5

# %%
df[df['Average Rating'] > 4.5]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
df[df['Average Rating'] > 4.5]['Total Feedback']
# Out:
# 2       11
# 3        7
# 5        8
# 6       12
# 7        6
#         ..
# 2100    13
# 2101    13
# 2102    14
# 2103    18
# 2104     9
# Name: Total Feedback, Length: 307, dtype: int64

# %%
l = []
for i in df['Agent Name']:
    l.append(i)
    

list_of_Agent = set(l)

print(list(list_of_Agent))
# Out:
# ['Spuri ', 'Chaitra K Hiremath', 'Mahak ', 'Deepranjan Gupta', 'Saurabh Shukla', 'Mahesh Sarade', 'Aditya Shinde', 'Suraj S Bilgi', 'Abhishek ', 'Anurag Tiwari', 'Dibyanshu ', 'Ankit Sharma', 'Maneesh ', 'Shivan K', 'Muskan Garg', 'Shubham Sharma', 'Nishtha Jain', 'Nandani Gupta', 'Ineuron Intelligence ', 'Ankitjha ', 'Aditya_iot ', 'Hyder Abbas', 'Prabir Kumar Satapathy', 'Prerna Singh', 'Hitesh Choudhary', 'Shiva Srivastava', 'Mukesh ', 'Saikumarreddy N', 'Boktiar Ahmed Bappy', 'Zeeshan ', 'Ameya Jain', 'Amersh ', 'Swati ', 'Vivek ', 'Nitin M', 'Sandipan Saha', 'Uday Mishra', 'Shivananda Sonwane', 'Mithun S', 'Sanjeevan ', 'Manjunatha A', 'Maitry ', 'Mukesh Rao ', 'Harikrishnan Shaji', 'Khushboo Priya', 'Sudhanshu Kumar', 'Aditya ', 'Wasim ', 'Ashish ', 'Jaydeep Dixit', 'Ishawant Kumar', 'Samprit ', 'Ashad Nasim', 'Vasanth P', 'Madhulika G', 'Aravind ', 'Shivan_S ', 'Ayushi Mishra', 'Prateek _iot ', 'Rishav Dash', 'Hrisikesh Neogi', 'Jayant Kumar', 'Jawala Prakash', 'Tarun ', 'Rohan ', 'Bharath ', 'Anirudh ', 'Saif Khan', 'Sanjeev Kumar', 'Sowmiya Sivakumar']
